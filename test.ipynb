# %%
a=257
b=257

# %%
print(id(a))
print(id(b))
# Out:
# 137442191419184
# 137442191418192

# %%
if "c":
    print("True")
# Out:
# True

# %%
.3 == round((.2 + .1), 1)
# Out:
# True

# %%
x = int(input("add a number: "))

# %%
print('a+',b,'')
# Out:
# a+ 257
